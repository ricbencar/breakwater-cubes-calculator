# %% [markdown]
# # Breakwater Calculator Notebook
#
# This notebook reproduces the same calculations and the same printed/file report as the attached `breakwater_calculator_cli.cpp`.

# %%
import math
from pathlib import Path

FORMULAS = {
    1: {
        "name": "Van der Meer (1988a) - Simple Cubes (Slope 2.0:1)",
        "type": "Cubes",
        "slope_ratio": 2.0,
        "k1": 7.374304189198,
        "k2": 0.4,
        "k3": 0.3,
        "k4": 1.100642416298,
        "k5": 0.1,
    },
    2: {
        "name": "Van Der Meer (1988a) - Simple Cubes (Slope 1.5:1)",
        "type": "Cubes",
        "slope_ratio": 1.5,
        "k1": 6.7,
        "k2": 0.4,
        "k3": 0.3,
        "k4": 1.0,
        "k5": 0.1,
    },
    3: {
        "name": "Chegini-Aghtouman (2006) - Antifer (Slope 2:1)",
        "type": "Antifer",
        "slope_ratio": 2.0,
        "k1": 6.138,
        "k2": 0.443,
        "k3": 0.276,
        "k4": 1.164,
        "k5": 0.07,
    },
    4: {
        "name": "Chegini-Aghtouman (2006) - Antifer (Slope 1.5:1)",
        "type": "Antifer",
        "slope_ratio": 1.5,
        "k1": 6.951,
        "k2": 0.443,
        "k3": 0.291,
        "k4": 1.082,
        "k5": 0.082,
    },
}

STANDARD_GRADINGS = [
    {"name": "CP32/90",        "NLL_kg": 0.868,   "NUL_kg": 19.319},
    {"name": "CP45/125",       "NLL_kg": 2.415,   "NUL_kg": 51.758},
    {"name": "CP63/180",       "NLL_kg": 6.626,   "NUL_kg": 154.548},
    {"name": "CP90/250",       "NLL_kg": 19.319,  "NUL_kg": 414.063},
    {"name": "CP45/180",       "NLL_kg": 2.415,   "NUL_kg": 154.548},
    {"name": "CP90/180",       "NLL_kg": 19.319,  "NUL_kg": 154.548},
    {"name": "LMA5-40",        "NLL_kg": 5.0,     "NUL_kg": 40.0},
    {"name": "LMA10-60",       "NLL_kg": 10.0,    "NUL_kg": 60.0},
    {"name": "LMA15-120",      "NLL_kg": 15.0,    "NUL_kg": 120.0},
    {"name": "LMA40-200",      "NLL_kg": 40.0,    "NUL_kg": 200.0},
    {"name": "LMA60-300",      "NLL_kg": 60.0,    "NUL_kg": 300.0},
    {"name": "LMA15-300",      "NLL_kg": 15.0,    "NUL_kg": 300.0},
    {"name": "HMA300-1000",    "NLL_kg": 300.0,   "NUL_kg": 1000.0},
    {"name": "HMA1000-3000",   "NLL_kg": 1000.0,  "NUL_kg": 3000.0},
    {"name": "HMA3000-6000",   "NLL_kg": 3000.0,  "NUL_kg": 6000.0},
    {"name": "HMA6000-10000",  "NLL_kg": 6000.0,  "NUL_kg": 10000.0},
    {"name": "HMA10000-15000", "NLL_kg": 10000.0, "NUL_kg": 15000.0},
]


class BreakwaterCalculator:
    def __init__(self):
        self.g = 9.80665
        self.W_rock_spec = 26.5
        self.P_cubes = 0.40
        self.P_rock = 0.25
        self.KD_RATIO_FIXED = 1.5
        self.formulas = FORMULAS
        self.standard_gradings = STANDARD_GRADINGS
        self.defaults = {
            "Hs": 11.0,
            "Tm": 11.9,
            "Number_of_Waves": 3000.0,
            "Nod": 0.5,
            "Wc": 27.48,
            "Ww": 10.05,
            "Formula_ID": 1,
        }

    def calculate_L0(self, Tm):
        return (self.g * (Tm ** 2)) / (2.0 * math.pi)

    def calculate_underlayer_params(self, W_armor):
        target_weight = W_armor / 10.0
        target_mass_kg = (target_weight * 1000.0) / self.g

        selected_grading = None
        found = False
        final_M50 = 0.0
        final_NLL = 0.0
        final_NUL = 0.0
        min_range_width = float("inf")

        for grading in self.standard_gradings:
            if target_mass_kg > grading["NLL_kg"] and target_mass_kg < grading["NUL_kg"]:
                current_range = grading["NUL_kg"] - grading["NLL_kg"]
                if current_range < min_range_width:
                    min_range_width = current_range
                    selected_grading = grading
                    final_NLL = grading["NLL_kg"]
                    final_NUL = grading["NUL_kg"]
                    final_M50 = 0.5 * (final_NLL + final_NUL)
                    found = True

        if (not found) and self.standard_gradings:
            selected_grading = self.standard_gradings[0]
            final_NLL = selected_grading["NLL_kg"]
            final_NUL = selected_grading["NUL_kg"]
            final_M50 = 0.5 * (final_NLL + final_NUL)

        ELL = 0.7 * final_NLL
        EUL = 1.5 * final_NUL
        W_mean_kn = (final_M50 * self.g) / 1000.0
        Dn_rock = (W_mean_kn / self.W_rock_spec) ** (1.0 / 3.0)
        r2 = 2.0 * Dn_rock
        f2 = 100.0 * 2.0 * 1.0 * (1.0 - self.P_rock) / (Dn_rock ** 2)

        return {
            "grading_name": selected_grading["name"],
            "target_W": target_weight,
            "target_M50_kg": target_mass_kg,
            "M50_kg": final_M50,
            "NLL_kg": final_NLL,
            "NUL_kg": final_NUL,
            "ELL_kg": ELL,
            "EUL_kg": EUL,
            "W_mean_kn": W_mean_kn,
            "Dn_rock": Dn_rock,
            "r2": r2,
            "f2": f2,
            "W_rock_spec": self.W_rock_spec,
        }

    def solve(self, formula_id, params):
        if formula_id not in self.formulas:
            raise RuntimeError("Invalid Formula ID")

        coeffs = self.formulas[formula_id]
        k1 = coeffs["k1"]
        k2 = coeffs["k2"]
        k3 = coeffs["k3"]
        k4 = coeffs["k4"]
        k5 = coeffs["k5"]

        L0 = self.calculate_L0(params["Tm"])
        k0 = (2.0 * math.pi) / L0
        s0m = params["Hs"] / L0
        sm = s0m

        Nz = params["Number_of_Waves"]
        storm_duration_hr = (Nz * params["Tm"]) / 3600.0
        delta_trunk = (params["Wc"] / params["Ww"]) - 1.0

        term_damage = params["Nod"] ** k2
        term_waves = Nz ** k3
        damage_wave_ratio = term_damage / term_waves
        scaled_term = k1 * damage_wave_ratio
        inv_f = scaled_term + k4
        steepness_factor = s0m ** (-k5)
        Ns_trunk = inv_f * steepness_factor

        Dn = params["Hs"] / (delta_trunk * Ns_trunk)
        W_trunk = params["Wc"] * (Dn ** 3)
        packing_density_trunk = 100.0 * 2.0 * 1.1 * (1.0 - self.P_cubes) / (Dn ** 2)

        slope = coeffs["slope_ratio"]
        kd_trunk_equiv = (params["Wc"] * (params["Hs"] ** 3)) / (
            W_trunk * (delta_trunk ** 3) * slope
        )

        ul_trunk = self.calculate_underlayer_params(W_trunk)

        kd_ratio = self.KD_RATIO_FIXED
        kd_head_derived = kd_trunk_equiv / kd_ratio
        delta_head = delta_trunk * (kd_ratio ** (1.0 / 3.0))
        Wc_head = params["Ww"] * (delta_head + 1.0)
        W_head = W_trunk * (Wc_head / params["Wc"])

        Ns_head = params["Hs"] / (delta_head * Dn)
        packing_density_head = 100.0 * 2.0 * 1.1 * (1.0 - self.P_cubes) / (Dn ** 2)

        ul_head = self.calculate_underlayer_params(W_head)

        r1 = 2.0 * 1.1 * Dn

        vol_trunk = W_trunk / params["Wc"]
        h_trunk = (vol_trunk / 1.0247) ** (1.0 / 3.0)
        a_trunk = 1.086 * h_trunk
        b_trunk = 1.005 * h_trunk

        vol_head = W_head / Wc_head
        h_head = (vol_head / 1.0247) ** (1.0 / 3.0)
        a_head = 1.086 * h_head
        b_head = 1.005 * h_head

        return {
            "inputs": dict(params),
            "coefficients": dict(coeffs),
            "intermediate": {
                "L0": L0,
                "k0": k0,
                "s0m": s0m,
                "sm": sm,
                "Nz": Nz,
                "Storm_Duration_hr": storm_duration_hr,
                "delta": delta_trunk,
                "Ns_trunk": Ns_trunk,
            },
            "final_trunk": {
                "Dn": Dn,
                "W": W_trunk,
                "Mass_tonnes": W_trunk / self.g,
                "Kd": kd_trunk_equiv,
                "r1": r1,
                "packing_density": packing_density_trunk,
                "dims": {"H": h_trunk, "A": a_trunk, "B": b_trunk},
            },
            "underlayer_trunk": ul_trunk,
            "final_head": {
                "Ns": Ns_head,
                "Dn": Dn,
                "Kd": kd_head_derived,
                "Kd_Ratio": kd_ratio,
                "Delta_Required": delta_head,
                "Wc_Required": Wc_head,
                "W": W_head,
                "Mass_tonnes": W_head / self.g,
                "packing_density": packing_density_head,
                "dims": {"H": h_head, "A": a_head, "B": b_head},
            },
            "underlayer_head": ul_head,
            "P_rock": self.P_rock,
            "P_cubes": self.P_cubes,
        }

    def build_report_content(self, results):
        def fmt(val, prec):
            return f"{val:.{prec}f}"

        p = results["inputs"]
        c = results["coefficients"]
        i = results["intermediate"]
        ft = results["final_trunk"]
        ut = results["underlayer_trunk"]
        fh = results["final_head"]
        uh = results["underlayer_head"]

        trunk_volume = 1.0247 * (ft["dims"]["H"] ** 3) if c["type"] == "Antifer" else (ft["Dn"] ** 3)
        head_volume = 1.0247 * (fh["dims"]["H"] ** 3) if c["type"] == "Antifer" else (fh["Dn"] ** 3)

        lines = []
        lines.append("================================================================================")
        lines.append("    TECHNICAL REPORT: BREAKWATER ARMOR & UNDERLAYER DESIGN                        ")
        lines.append("================================================================================")
        lines.append(f"Methodology: {c['name']}")
        lines.append("-" * 80)

        lines.append("1. INPUT PARAMETERS")
        lines.append(f"   Hs (Sigificant Wave Height)         : {fmt(p['Hs'], 2)} m")
        lines.append(f"   Tm (Mean Wave Period)               : {fmt(p['Tm'], 2)} s")
        lines.append(f"   Number of waves (Nz)                : {fmt(p['Number_of_Waves'], 0)}")
        lines.append(f"   Nod (Damage)                        : {fmt(p['Nod'], 2)}")
        lines.append(f"   Wc Trunk (Concrete Spec. Weight)    : {fmt(p['Wc'], 2)} kN/m3")
        lines.append(f"   Ww (Water Specific Weight)          : {fmt(p['Ww'], 2)} kN/m3")
        lines.append(f"   Relative Density D=(Wc/Ww)-1        : {fmt(i['delta'], 4)}")
        lines.append(f"   Structure Slope (TRUNK & HEAD)      : {fmt(c['slope_ratio'], 1)}:1")
        lines.append(f"   Porosity (Cubes)                    : {fmt(results['P_cubes'] * 100.0, 0)}%")
        lines.append(f"   Porosity (Rock Layer)               : {fmt(results['P_rock'] * 100.0, 0)}%")
        lines.append("-" * 80)

        lines.append("2. INTERMEDIATE PARAMETERS")
        lines.append(f"   Wave Length (L0)                    : {fmt(i['L0'], 2)} m")
        lines.append(f"   wave number (k0 = 2*pi/L0)          : {fmt(i['k0'], 4)}")
        lines.append(f"   wave steepness (s0m = Hs/L0)        : {fmt(i['s0m'], 4)}")
        lines.append(f"   Storm Duration (h)                  : {fmt(i['Storm_Duration_hr'], 3)} h")
        lines.append(f"   Stability Number TRUNK (Ns)         : {fmt(i['Ns_trunk'], 4)}")
        lines.append(f"   Stability Number HEAD (Ns)          : {fmt(fh['Ns'], 4)}")
        lines.append("-" * 80)

        lines.append("3. ARMOR LAYER RESULTS - TRUNK")
        lines.append(f"   BLOCK WEIGHT (W)                    : {fmt(ft['W'], 2)} kN")
        lines.append(f"   Mass (ton)                          : {fmt(ft['Mass_tonnes'], 2)} t")
        lines.append(f"   Nominal Diameter (Dn)               : {fmt(ft['Dn'], 3)} m")
        if c["type"] == "Antifer":
            lines.append(f"   Volume = 1.0247 * H^3 (V)           : {fmt(trunk_volume, 3)} m3")
            lines.append(f"   Cube Height (H)                     : {fmt(ft['dims']['H'], 3)} m")
            lines.append(f"   Cube Top Width (B)                  : {fmt(ft['dims']['B'], 3)} m")
            lines.append(f"   Cube Base Width (A)                 : {fmt(ft['dims']['A'], 3)} m")
        else:
            lines.append(f"   Volume = Dn^3 (V)                   : {fmt(trunk_volume, 3)} m3")
        lines.append(f"   KD_TRUNK (Equivalent)               : {fmt(ft['Kd'], 2)}")
        lines.append(f"   Double Layer Thickness (r1)         : {fmt(ft['r1'], 2)} m")
        lines.append(f"   Packing Density, d [units/100m2]    : {fmt(ft['packing_density'], 2)}")
        lines.append("")

        lines.append("4. UNDERLAYER RESULTS - TRUNK")
        lines.append(f"   Theoretical Target (W/10)           : {fmt(ut['target_W'], 2)} kN ({fmt(ut['target_M50_kg'], 1)} kg)")
        lines.append(f"   Adopted rock grading                : {ut['grading_name']}")
        lines.append(f"   Representative M50                  : {fmt(ut['M50_kg'], 1)} kg")
        lines.append(f"   Nominal lower limit (NLL)           : {fmt(ut['NLL_kg'], 1)} kg")
        lines.append(f"   Nominal upper limit (NUL)           : {fmt(ut['NUL_kg'], 1)} kg")
        lines.append(f"   Extreme lower limit (ELL)           : {fmt(ut['ELL_kg'], 1)} kg")
        lines.append(f"   Extreme upper limit (EUL)           : {fmt(ut['EUL_kg'], 1)} kg")
        lines.append(f"   Nominal Diameter (Dn_rock)          : {fmt(ut['Dn_rock'], 3)} m")
        lines.append(f"   Double Layer Thickness (r2)         : {fmt(ut['r2'], 2)} m")
        lines.append(f"   Packing Density, f2 [rocks/100m2]   : {fmt(ut['f2'], 2)}")
        lines.append("-" * 80)

        lines.append("5. ARMOR LAYER RESULTS - HEAD (High Density)")
        lines.append("   *Maintains same Dn and Slope as Trunk*")
        lines.append(f"   Stability Ratio (Kd_T/Kd_H)         : {fmt(fh['Kd_Ratio'], 2)}")
        lines.append(f"   Nominal Diameter (Dn)               : {fmt(fh['Dn'], 3)} m")
        if c["type"] == "Antifer":
            lines.append(f"   Volume = 1.0247 * H^3 (V)           : {fmt(head_volume, 3)} m3")
            lines.append(f"   Cube Height (H)                     : {fmt(fh['dims']['H'], 3)} m")
            lines.append(f"   Cube Top width (B)                  : {fmt(fh['dims']['B'], 3)} m")
            lines.append(f"   Cube Base Width (A)                 : {fmt(fh['dims']['A'], 3)} m")
        else:
            lines.append(f"   Volume = Dn^3 (V)                   : {fmt(head_volume, 3)} m3")
        lines.append(f"   KD_HEAD (Equivalent)                : {fmt(fh['Kd'], 2)}")
        lines.append(f"   Required Concrete Density (Wc)      : {fmt(fh['Wc_Required'], 2)} kN/m3")
        lines.append(f"   BLOCK WEIGHT (W)                    : {fmt(fh['W'], 2)} kN")
        lines.append(f"   Mass (ton)                          : {fmt(fh['Mass_tonnes'], 2)} t")
        lines.append(f"   Packing Density, d [units/100m2]    : {fmt(fh['packing_density'], 2)}")
        lines.append("")

        lines.append("6. UNDERLAYER RESULTS - HEAD")
        lines.append(f"   Theoretical Target (W/10)           : {fmt(uh['target_W'], 2)} kN ({fmt(uh['target_M50_kg'], 1)} kg)")
        lines.append(f"   Adopted rock grading                : {uh['grading_name']}")
        lines.append(f"   Representative M50                  : {fmt(uh['M50_kg'], 1)} kg")
        lines.append(f"   Nominal lower limit (NLL)           : {fmt(uh['NLL_kg'], 1)} kg")
        lines.append(f"   Nominal upper limit (NUL)           : {fmt(uh['NUL_kg'], 1)} kg")
        lines.append(f"   Extreme lower limit (ELL)           : {fmt(uh['ELL_kg'], 1)} kg")
        lines.append(f"   Extreme upper limit (EUL)           : {fmt(uh['EUL_kg'], 1)} kg")
        lines.append(f"   Nominal Diameter (Dn_rock)          : {fmt(uh['Dn_rock'], 3)} m")
        lines.append(f"   Double Layer Thickness (r2)         : {fmt(uh['r2'], 2)} m")
        lines.append(f"   Packing Density, f2 [rocks/100m2]   : {fmt(uh['f2'], 2)}")
        lines.append("================================================================================")

        return "\n".join(lines)

    def generate_report_file(self, results, filepath="output.txt"):
        report_content = self.build_report_content(results)
        Path(filepath).write_text(report_content, encoding="utf-8")
        print(f"\n Report generated successfully: {filepath}")
        print("Report content:\n")
        print(report_content)
        return report_content


# ==============================================================================
# INPUT PARAMETERS
# ==============================================================================
# Edit the inputs below to match the reference CLI behavior.

inputs = {
    "Hs": 11.0,
    "Tm": 11.9,
    "Number_of_Waves": 3000.0,
    "Nod": 0.5,
    "Wc": 27.48,
    "Ww": 10.05,
    "Formula_ID": 1,
}

formula_id = inputs["Formula_ID"]

calc = BreakwaterCalculator()
results = calc.solve(formula_id, inputs)
report_content = calc.generate_report_file(results, "output.txt")
# Out:
#  Report generated successfully: output.txt
# Report content:
#
# ...
#     TECHNICAL REPORT: BREAKWATER ARMOR & UNDERLAYER DESIGN
# ...
# Methodology: Van der Meer (1988a) - Simple Cubes (Slope 2.0:1)
# --------------------------------------------------------------------------------
# 1. INPUT PARAMETERS
#    Hs (Sigificant Wave Height)         : 11.00 m
#    Tm (Mean Wave Period)               : 11.90 s
#    Number of waves (Nz)                : 3000
#    Nod (Damage)                        : 0.50
#    Wc Trunk (Concrete Spec. Weight)    : 27.48 kN/m3
#    Ww (Water Specific Weight)          : 10.05 kN/m3
#    Relative Density D=(Wc/Ww)-1        : 1.7343
#    Structure Slope (TRUNK & HEAD)      : 2.0:1
#    Porosity (Cubes)                    : 40%
#    Porosity (Rock Layer)               : 25%
# --------------------------------------------------------------------------------
# 2. INTERMEDIATE PARAMETERS
#    Wave Length (L0)                    : 221.02 m
# ...

# %% [markdown]
# ## Formula options
#
# - `1` — Simple Cubes (Slope 2.0:1) — Van der Meer
# - `2` — Simple Cubes (Slope 1.5:1) — Van der Meer
# - `3` — Antifer (Slope 2.0:1) — Chegini
# - `4` — Antifer (Slope 1.5:1) — Chegini
#
# The notebook writes `output.txt` with the same overwrite behavior as the attached CLI.
